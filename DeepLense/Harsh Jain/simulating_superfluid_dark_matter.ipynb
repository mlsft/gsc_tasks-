# %% [markdown]
# __SIMULATING STRONG LENSING WITH FLUID DARK MATTER__
# Considering fluid dark matter as a string of mass on a "galactic" scale

# %%
# %matplotlib inline

import autolens as al
import autolens.plot as aplt

# %%
psf = al.kernel.from_gaussian(shape_2d=(11, 11), sigma=0.1, pixel_scales=0.1)

# %%
grid = al.grid.uniform(
    shape_2d=(100, 100), pixel_scales=0.1, sub_size=2
)

# %% [markdown]
# Setting up the lens "galaxy" or rather the string of fluid dark matter (just a lot of point masses next to one another) stretching from (y,x):(0,-2) to (0,2)

# %%
lens_galaxy = al.Galaxy(
    redshift=0.5,
  mass_1=al.mp.PointMass(
        centre=(0.0, -2.00), einstein_radius=1.6
    ),
mass_2=al.mp.PointMass(centre=(0.0,-1.99),einstein_radius=1.6),
mass_3=al.mp.PointMass(centre=(0.0,-1.98),einstein_radius=1.6),mass_4=al.mp.PointMass(centre=(0.0,-1.97),einstein_radius=1.6),
mass_5=al.mp.PointMass(centre=(0.0,-1.96),einstein_radius=1.6),mass_6=al.mp.PointMass(centre=(0.0,-1.95),einstein_radius=1.6),
mass_7=al.mp.PointMass(centre=(0.0,-1.94),einstein_radius=1.6),mass_8=al.mp.PointMass(centre=(0.0,-1.93),einstein_radius=1.6),
mass_9=al.mp.PointMass(centre=(0.0,-1.92),einstein_radius=1.6),mass_10=al.mp.PointMass(centre=(0.0,-1.91),einstein_radius=1.6),
mass_11=al.mp.PointMass(centre=(0.0,-1.9),einstein_radius=1.6),mass_12=al.mp.PointMass(centre=(0.0,-1.89),einstein_radius=1.6),
mass_13=al.mp.PointMass(centre=(0.0,-1.88),einstein_radius=1.6),mass_14=al.mp.PointMass(centre=(0.0,-1.8699999999999999),einstein_radius=1.6),
mass_15=al.mp.PointMass(centre=(0.0,-1.8599999999999999),einstein_radius=1.6),mass_16=al.mp.PointMass(centre=(0.0,-1.8499999999999999),einstein_radius=1.6),
mass_17=al.mp.PointMass(centre=(0.0,-1.8399999999999999),einstein_radius=1.6),mass_18=al.mp.PointMass(centre=(0.0,-1.8299999999999998),einstein_radius=1.6),
mass_19=al.mp.PointMass(centre=(0.0,-1.8199999999999998),einstein_radius=1.6),mass_20=al.mp.PointMass(centre=(0.0,-1.8099999999999998),einstein_radius=1.6),
mass_21=al.mp.PointMass(centre=(0.0,-1.7999999999999998),einstein_radius=1.6),mass_22=al.mp.PointMass(centre=(0.0,-1.7899999999999998),einstein_radius=1.6),
mass_23=al.mp.PointMass(centre=(0.0,-1.7799999999999998),einstein_radius=1.6),mass_24=al.mp.PointMass(centre=(0.0,-1.7699999999999998),einstein_radius=1.6),
mass_25=al.mp.PointMass(centre=(0.0,-1.7599999999999998),einstein_radius=1.6),mass_26=al.mp.PointMass(centre=(0.0,-1.7499999999999998),einstein_radius=1.6),
mass_27=al.mp.PointMass(centre=(0.0,-1.7399999999999998),einstein_radius=1.6),mass_28=al.mp.PointMass(centre=(0.0,-1.7299999999999998),einstein_radius=1.6),
mass_29=al.mp.PointMass(centre=(0.0,-1.7199999999999998),einstein_radius=1.6),mass_30=al.mp.PointMass(centre=(0.0,-1.7099999999999997),einstein_radius=1.6),
mass_31=al.mp.PointMass(centre=(0.0,-1.6999999999999997),einstein_radius=1.6),mass_32=al.mp.PointMass(centre=(0.0,-1.6899999999999997),einstein_radius=1.6),
mass_33=al.mp.PointMass(centre=(0.0,-1.6799999999999997),einstein_radius=1.6),mass_34=al.mp.PointMass(centre=(0.0,-1.6699999999999997),einstein_radius=1.6),
mass_35=al.mp.PointMass(centre=(0.0,-1.6599999999999997),einstein_radius=1.6),
mass_36=al.mp.PointMass(centre=(0.0,-1.6499999999999997),einstein_radius=1.6),
mass_37=al.mp.PointMass(centre=(0.0,-1.6399999999999997),einstein_radius=1.6),
mass_38=al.mp.PointMass(centre=(0.0,-1.6299999999999997),einstein_radius=1.6),
mass_39=al.mp.PointMass(centre=(0.0,-1.6199999999999997),einstein_radius=1.6),
mass_40=al.mp.PointMass(centre=(0.0,-1.6099999999999997),einstein_radius=1.6),
mass_41=al.mp.PointMass(centre=(0.0,-1.5999999999999996),einstein_radius=1.6),
mass_42=al.mp.PointMass(centre=(0.0,-1.5899999999999996),einstein_radius=1.6),
mass_43=al.mp.PointMass(centre=(0.0,-1.5799999999999996),einstein_radius=1.6),
mass_44=al.mp.PointMass(centre=(0.0,-1.5699999999999996),einstein_radius=1.6),
mass_45=al.mp.PointMass(centre=(0.0,-1.5599999999999996),einstein_radius=1.6),
mass_46=al.mp.PointMass(centre=(0.0,-1.5499999999999996),einstein_radius=1.6),
mass_47=al.mp.PointMass(centre=(0.0,-1.5399999999999996),einstein_radius=1.6),
mass_48=al.mp.PointMass(centre=(0.0,-1.5299999999999996),einstein_radius=1.6),
mass_49=al.mp.PointMass(centre=(0.0,-1.5199999999999996),einstein_radius=1.6),
mass_50=al.mp.PointMass(centre=(0.0,-1.5099999999999996),einstein_radius=1.6),
mass_51=al.mp.PointMass(centre=(0.0,-1.4999999999999996),einstein_radius=1.6),
mass_52=al.mp.PointMass(centre=(0.0,-1.4899999999999995),einstein_radius=1.6),
mass_53=al.mp.PointMass(centre=(0.0,-1.4799999999999995),einstein_radius=1.6),
mass_54=al.mp.PointMass(centre=(0.0,-1.4699999999999995),einstein_radius=1.6),
mass_55=al.mp.PointMass(centre=(0.0,-1.4599999999999995),einstein_radius=1.6),
mass_56=al.mp.PointMass(centre=(0.0,-1.4499999999999995),einstein_radius=1.6),
mass_57=al.mp.PointMass(centre=(0.0,-1.4399999999999995),einstein_radius=1.6),
mass_58=al.mp.PointMass(centre=(0.0,-1.4299999999999995),einstein_radius=1.6),
mass_59=al.mp.PointMass(centre=(0.0,-1.4199999999999995),einstein_radius=1.6),
mass_60=al.mp.PointMass(centre=(0.0,-1.4099999999999995),einstein_radius=1.6),
mass_61=al.mp.PointMass(centre=(0.0,-1.3999999999999995),einstein_radius=1.6),
mass_62=al.mp.PointMass(centre=(0.0,-1.3899999999999995),einstein_radius=1.6),
mass_63=al.mp.PointMass(centre=(0.0,-1.3799999999999994),einstein_radius=1.6),
mass_64=al.mp.PointMass(centre=(0.0,-1.3699999999999994),einstein_radius=1.6),
mass_65=al.mp.PointMass(centre=(0.0,-1.3599999999999994),einstein_radius=1.6),
mass_66=al.mp.PointMass(centre=(0.0,-1.3499999999999994),einstein_radius=1.6),
mass_67=al.mp.PointMass(centre=(0.0,-1.3399999999999994),einstein_radius=1.6),
mass_68=al.mp.PointMass(centre=(0.0,-1.3299999999999994),einstein_radius=1.6),
mass_69=al.mp.PointMass(centre=(0.0,-1.3199999999999994),einstein_radius=1.6),
mass_70=al.mp.PointMass(centre=(0.0,-1.3099999999999994),einstein_radius=1.6),
mass_71=al.mp.PointMass(centre=(0.0,-1.2999999999999994),einstein_radius=1.6),
mass_72=al.mp.PointMass(centre=(0.0,-1.2899999999999994),einstein_radius=1.6),
mass_73=al.mp.PointMass(centre=(0.0,-1.2799999999999994),einstein_radius=1.6),
mass_74=al.mp.PointMass(centre=(0.0,-1.2699999999999994),einstein_radius=1.6),
mass_75=al.mp.PointMass(centre=(0.0,-1.2599999999999993),einstein_radius=1.6),
mass_76=al.mp.PointMass(centre=(0.0,-1.2499999999999993),einstein_radius=1.6),
mass_77=al.mp.PointMass(centre=(0.0,-1.2399999999999993),einstein_radius=1.6),
mass_78=al.mp.PointMass(centre=(0.0,-1.2299999999999993),einstein_radius=1.6),
mass_79=al.mp.PointMass(centre=(0.0,-1.2199999999999993),einstein_radius=1.6),
mass_80=al.mp.PointMass(centre=(0.0,-1.2099999999999993),einstein_radius=1.6),
mass_81=al.mp.PointMass(centre=(0.0,-1.1999999999999993),einstein_radius=1.6),
mass_82=al.mp.PointMass(centre=(0.0,-1.1899999999999993),einstein_radius=1.6),
mass_83=al.mp.PointMass(centre=(0.0,-1.1799999999999993),einstein_radius=1.6),
mass_84=al.mp.PointMass(centre=(0.0,-1.1699999999999993),einstein_radius=1.6),
mass_85=al.mp.PointMass(centre=(0.0,-1.1599999999999993),einstein_radius=1.6),
mass_86=al.mp.PointMass(centre=(0.0,-1.1499999999999992),einstein_radius=1.6),
mass_87=al.mp.PointMass(centre=(0.0,-1.1399999999999992),einstein_radius=1.6),
mass_88=al.mp.PointMass(centre=(0.0,-1.1299999999999992),einstein_radius=1.6),
mass_89=al.mp.PointMass(centre=(0.0,-1.1199999999999992),einstein_radius=1.6),
mass_90=al.mp.PointMass(centre=(0.0,-1.1099999999999992),einstein_radius=1.6),
mass_91=al.mp.PointMass(centre=(0.0,-1.0999999999999992),einstein_radius=1.6),
mass_92=al.mp.PointMass(centre=(0.0,-1.0899999999999992),einstein_radius=1.6),
mass_93=al.mp.PointMass(centre=(0.0,-1.0799999999999992),einstein_radius=1.6),
mass_94=al.mp.PointMass(centre=(0.0,-1.0699999999999992),einstein_radius=1.6),
mass_95=al.mp.PointMass(centre=(0.0,-1.0599999999999992),einstein_radius=1.6),
mass_96=al.mp.PointMass(centre=(0.0,-1.0499999999999992),einstein_radius=1.6),
mass_97=al.mp.PointMass(centre=(0.0,-1.0399999999999991),einstein_radius=1.6),
mass_98=al.mp.PointMass(centre=(0.0,-1.0299999999999991),einstein_radius=1.6),
mass_99=al.mp.PointMass(centre=(0.0,-1.0199999999999991),einstein_radius=1.6),
mass_100=al.mp.PointMass(centre=(0.0,-1.0099999999999991),einstein_radius=1.6),
mass_101=al.mp.PointMass(centre=(0.0,-0.9999999999999991),einstein_radius=1.6),
mass_102=al.mp.PointMass(centre=(0.0,-0.9899999999999991),einstein_radius=1.6),
mass_103=al.mp.PointMass(centre=(0.0,-0.9799999999999991),einstein_radius=1.6),
mass_104=al.mp.PointMass(centre=(0.0,-0.9699999999999991),einstein_radius=1.6),
mass_105=al.mp.PointMass(centre=(0.0,-0.9599999999999991),einstein_radius=1.6),
mass_106=al.mp.PointMass(centre=(0.0,-0.9499999999999991),einstein_radius=1.6),
mass_107=al.mp.PointMass(centre=(0.0,-0.9399999999999991),einstein_radius=1.6),
mass_108=al.mp.PointMass(centre=(0.0,-0.929999999999999),einstein_radius=1.6),
mass_109=al.mp.PointMass(centre=(0.0,-0.919999999999999),einstein_radius=1.6),
mass_110=al.mp.PointMass(centre=(0.0,-0.909999999999999),einstein_radius=1.6),
mass_111=al.mp.PointMass(centre=(0.0,-0.899999999999999),einstein_radius=1.6),
mass_112=al.mp.PointMass(centre=(0.0,-0.889999999999999),einstein_radius=1.6),
mass_113=al.mp.PointMass(centre=(0.0,-0.879999999999999),einstein_radius=1.6),
mass_114=al.mp.PointMass(centre=(0.0,-0.869999999999999),einstein_radius=1.6),
mass_115=al.mp.PointMass(centre=(0.0,-0.859999999999999),einstein_radius=1.6),
mass_116=al.mp.PointMass(centre=(0.0,-0.849999999999999),einstein_radius=1.6),
mass_117=al.mp.PointMass(centre=(0.0,-0.839999999999999),einstein_radius=1.6),
mass_118=al.mp.PointMass(centre=(0.0,-0.829999999999999),einstein_radius=1.6),
mass_119=al.mp.PointMass(centre=(0.0,-0.819999999999999),einstein_radius=1.6),
mass_120=al.mp.PointMass(centre=(0.0,-0.8099999999999989),einstein_radius=1.6),
mass_121=al.mp.PointMass(centre=(0.0,-0.7999999999999989),einstein_radius=1.6),
mass_122=al.mp.PointMass(centre=(0.0,-0.7899999999999989),einstein_radius=1.6),
mass_123=al.mp.PointMass(centre=(0.0,-0.7799999999999989),einstein_radius=1.6),
mass_124=al.mp.PointMass(centre=(0.0,-0.7699999999999989),einstein_radius=1.6),
mass_125=al.mp.PointMass(centre=(0.0,-0.7599999999999989),einstein_radius=1.6),
mass_126=al.mp.PointMass(centre=(0.0,-0.7499999999999989),einstein_radius=1.6),
mass_127=al.mp.PointMass(centre=(0.0,-0.7399999999999989),einstein_radius=1.6),
mass_128=al.mp.PointMass(centre=(0.0,-0.7299999999999989),einstein_radius=1.6),
mass_129=al.mp.PointMass(centre=(0.0,-0.7199999999999989),einstein_radius=1.6),
mass_130=al.mp.PointMass(centre=(0.0,-0.7099999999999989),einstein_radius=1.6),
mass_131=al.mp.PointMass(centre=(0.0,-0.6999999999999988),einstein_radius=1.6),
mass_132=al.mp.PointMass(centre=(0.0,-0.6899999999999988),einstein_radius=1.6),
mass_133=al.mp.PointMass(centre=(0.0,-0.6799999999999988),einstein_radius=1.6),
mass_134=al.mp.PointMass(centre=(0.0,-0.6699999999999988),einstein_radius=1.6),
mass_135=al.mp.PointMass(centre=(0.0,-0.6599999999999988),einstein_radius=1.6),
mass_136=al.mp.PointMass(centre=(0.0,-0.6499999999999988),einstein_radius=1.6),
mass_137=al.mp.PointMass(centre=(0.0,-0.6399999999999988),einstein_radius=1.6),
mass_138=al.mp.PointMass(centre=(0.0,-0.6299999999999988),einstein_radius=1.6),
mass_139=al.mp.PointMass(centre=(0.0,-0.6199999999999988),einstein_radius=1.6),
mass_140=al.mp.PointMass(centre=(0.0,-0.6099999999999988),einstein_radius=1.6),
mass_141=al.mp.PointMass(centre=(0.0,-0.5999999999999988),einstein_radius=1.6),
mass_142=al.mp.PointMass(centre=(0.0,-0.5899999999999987),einstein_radius=1.6),
mass_143=al.mp.PointMass(centre=(0.0,-0.5799999999999987),einstein_radius=1.6),
mass_144=al.mp.PointMass(centre=(0.0,-0.5699999999999987),einstein_radius=1.6),
mass_145=al.mp.PointMass(centre=(0.0,-0.5599999999999987),einstein_radius=1.6),
mass_146=al.mp.PointMass(centre=(0.0,-0.5499999999999987),einstein_radius=1.6),
mass_147=al.mp.PointMass(centre=(0.0,-0.5399999999999987),einstein_radius=1.6),
mass_148=al.mp.PointMass(centre=(0.0,-0.5299999999999987),einstein_radius=1.6),
mass_149=al.mp.PointMass(centre=(0.0,-0.5199999999999987),einstein_radius=1.6),
mass_150=al.mp.PointMass(centre=(0.0,-0.5099999999999987),einstein_radius=1.6),
mass_151=al.mp.PointMass(centre=(0.0,-0.49999999999999867),einstein_radius=1.6),
mass_152=al.mp.PointMass(centre=(0.0,-0.48999999999999866),einstein_radius=1.6),
mass_153=al.mp.PointMass(centre=(0.0,-0.47999999999999865),einstein_radius=1.6),
mass_154=al.mp.PointMass(centre=(0.0,-0.46999999999999864),einstein_radius=1.6),
mass_155=al.mp.PointMass(centre=(0.0,-0.45999999999999863),einstein_radius=1.6),
mass_156=al.mp.PointMass(centre=(0.0,-0.4499999999999986),einstein_radius=1.6),
mass_157=al.mp.PointMass(centre=(0.0,-0.4399999999999986),einstein_radius=1.6),
mass_158=al.mp.PointMass(centre=(0.0,-0.4299999999999986),einstein_radius=1.6),
mass_159=al.mp.PointMass(centre=(0.0,-0.4199999999999986),einstein_radius=1.6),
mass_160=al.mp.PointMass(centre=(0.0,-0.4099999999999986),einstein_radius=1.6),
mass_161=al.mp.PointMass(centre=(0.0,-0.3999999999999986),einstein_radius=1.6),
mass_162=al.mp.PointMass(centre=(0.0,-0.38999999999999857),einstein_radius=1.6),
mass_163=al.mp.PointMass(centre=(0.0,-0.37999999999999856),einstein_radius=1.6),
mass_164=al.mp.PointMass(centre=(0.0,-0.36999999999999855),einstein_radius=1.6),
mass_165=al.mp.PointMass(centre=(0.0,-0.35999999999999854),einstein_radius=1.6),
mass_166=al.mp.PointMass(centre=(0.0,-0.34999999999999853),einstein_radius=1.6),
mass_167=al.mp.PointMass(centre=(0.0,-0.3399999999999985),einstein_radius=1.6),
mass_168=al.mp.PointMass(centre=(0.0,-0.3299999999999985),einstein_radius=1.6),
mass_169=al.mp.PointMass(centre=(0.0,-0.3199999999999985),einstein_radius=1.6),
mass_170=al.mp.PointMass(centre=(0.0,-0.3099999999999985),einstein_radius=1.6),
mass_171=al.mp.PointMass(centre=(0.0,-0.2999999999999985),einstein_radius=1.6),
mass_172=al.mp.PointMass(centre=(0.0,-0.2899999999999985),einstein_radius=1.6),
mass_173=al.mp.PointMass(centre=(0.0,-0.2799999999999985),einstein_radius=1.6),
mass_174=al.mp.PointMass(centre=(0.0,-0.26999999999999846),einstein_radius=1.6),
mass_175=al.mp.PointMass(centre=(0.0,-0.25999999999999845),einstein_radius=1.6),
mass_176=al.mp.PointMass(centre=(0.0,-0.24999999999999845),einstein_radius=1.6),
mass_177=al.mp.PointMass(centre=(0.0,-0.23999999999999844),einstein_radius=1.6),
mass_178=al.mp.PointMass(centre=(0.0,-0.22999999999999843),einstein_radius=1.6),
mass_179=al.mp.PointMass(centre=(0.0,-0.21999999999999842),einstein_radius=1.6),
mass_180=al.mp.PointMass(centre=(0.0,-0.2099999999999984),einstein_radius=1.6),
mass_181=al.mp.PointMass(centre=(0.0,-0.1999999999999984),einstein_radius=1.6),
mass_182=al.mp.PointMass(centre=(0.0,-0.1899999999999984),einstein_radius=1.6),
mass_183=al.mp.PointMass(centre=(0.0,-0.17999999999999838),einstein_radius=1.6),
mass_184=al.mp.PointMass(centre=(0.0,-0.16999999999999837),einstein_radius=1.6),
mass_185=al.mp.PointMass(centre=(0.0,-0.15999999999999837),einstein_radius=1.6),
mass_186=al.mp.PointMass(centre=(0.0,-0.14999999999999836),einstein_radius=1.6),
mass_187=al.mp.PointMass(centre=(0.0,-0.13999999999999835),einstein_radius=1.6),
mass_188=al.mp.PointMass(centre=(0.0,-0.12999999999999834),einstein_radius=1.6),
mass_189=al.mp.PointMass(centre=(0.0,-0.11999999999999834),einstein_radius=1.6),
mass_190=al.mp.PointMass(centre=(0.0,-0.10999999999999835),einstein_radius=1.6),
mass_191=al.mp.PointMass(centre=(0.0,-0.09999999999999835),einstein_radius=1.6),
mass_192=al.mp.PointMass(centre=(0.0,-0.08999999999999836),einstein_radius=1.6),
mass_193=al.mp.PointMass(centre=(0.0,-0.07999999999999836),einstein_radius=1.6),
mass_194=al.mp.PointMass(centre=(0.0,-0.06999999999999837),einstein_radius=1.6),
mass_195=al.mp.PointMass(centre=(0.0,-0.05999999999999837),einstein_radius=1.6),
mass_196=al.mp.PointMass(centre=(0.0,-0.049999999999998365),einstein_radius=1.6),
mass_197=al.mp.PointMass(centre=(0.0,-0.03999999999999836),einstein_radius=1.6),
mass_198=al.mp.PointMass(centre=(0.0,-0.02999999999999836),einstein_radius=1.6),
mass_199=al.mp.PointMass(centre=(0.0,-0.01999999999999836),einstein_radius=1.6),
mass_200=al.mp.PointMass(centre=(0.0,-0.00999999999999836),einstein_radius=1.6),
mass_201=al.mp.PointMass(centre=(0.0,1.6410484082740595e-15),einstein_radius=1.6),
mass_202=al.mp.PointMass(centre=(0.0,0.010000000000001641),einstein_radius=1.6),
mass_203=al.mp.PointMass(centre=(0.0,0.02000000000000164),einstein_radius=1.6),
mass_204=al.mp.PointMass(centre=(0.0,0.030000000000001643),einstein_radius=1.6),
mass_205=al.mp.PointMass(centre=(0.0,0.040000000000001645),einstein_radius=1.6),
mass_206=al.mp.PointMass(centre=(0.0,0.05000000000000165),einstein_radius=1.6),
mass_207=al.mp.PointMass(centre=(0.0,0.06000000000000165),einstein_radius=1.6),
mass_208=al.mp.PointMass(centre=(0.0,0.07000000000000164),einstein_radius=1.6),
mass_209=al.mp.PointMass(centre=(0.0,0.08000000000000164),einstein_radius=1.6),
mass_210=al.mp.PointMass(centre=(0.0,0.09000000000000163),einstein_radius=1.6),
mass_211=al.mp.PointMass(centre=(0.0,0.10000000000000163),einstein_radius=1.6),
mass_212=al.mp.PointMass(centre=(0.0,0.11000000000000162),einstein_radius=1.6),
mass_213=al.mp.PointMass(centre=(0.0,0.12000000000000162),einstein_radius=1.6),
mass_214=al.mp.PointMass(centre=(0.0,0.13000000000000161),einstein_radius=1.6),
mass_215=al.mp.PointMass(centre=(0.0,0.14000000000000162),einstein_radius=1.6),
mass_216=al.mp.PointMass(centre=(0.0,0.15000000000000163),einstein_radius=1.6),
mass_217=al.mp.PointMass(centre=(0.0,0.16000000000000164),einstein_radius=1.6),
mass_218=al.mp.PointMass(centre=(0.0,0.17000000000000165),einstein_radius=1.6),
mass_219=al.mp.PointMass(centre=(0.0,0.18000000000000166),einstein_radius=1.6),
mass_220=al.mp.PointMass(centre=(0.0,0.19000000000000167),einstein_radius=1.6),
mass_221=al.mp.PointMass(centre=(0.0,0.20000000000000168),einstein_radius=1.6),
mass_222=al.mp.PointMass(centre=(0.0,0.21000000000000169),einstein_radius=1.6),
mass_223=al.mp.PointMass(centre=(0.0,0.2200000000000017),einstein_radius=1.6),
mass_224=al.mp.PointMass(centre=(0.0,0.2300000000000017),einstein_radius=1.6),
mass_225=al.mp.PointMass(centre=(0.0,0.2400000000000017),einstein_radius=1.6),
mass_226=al.mp.PointMass(centre=(0.0,0.2500000000000017),einstein_radius=1.6),
mass_227=al.mp.PointMass(centre=(0.0,0.26000000000000173),einstein_radius=1.6),
mass_228=al.mp.PointMass(centre=(0.0,0.27000000000000174),einstein_radius=1.6),
mass_229=al.mp.PointMass(centre=(0.0,0.28000000000000175),einstein_radius=1.6),
mass_230=al.mp.PointMass(centre=(0.0,0.29000000000000176),einstein_radius=1.6),
mass_231=al.mp.PointMass(centre=(0.0,0.30000000000000177),einstein_radius=1.6),
mass_232=al.mp.PointMass(centre=(0.0,0.3100000000000018),einstein_radius=1.6),
mass_233=al.mp.PointMass(centre=(0.0,0.3200000000000018),einstein_radius=1.6),
mass_234=al.mp.PointMass(centre=(0.0,0.3300000000000018),einstein_radius=1.6),
mass_235=al.mp.PointMass(centre=(0.0,0.3400000000000018),einstein_radius=1.6),
mass_236=al.mp.PointMass(centre=(0.0,0.3500000000000018),einstein_radius=1.6),
mass_237=al.mp.PointMass(centre=(0.0,0.3600000000000018),einstein_radius=1.6),
mass_238=al.mp.PointMass(centre=(0.0,0.3700000000000018),einstein_radius=1.6),
mass_239=al.mp.PointMass(centre=(0.0,0.38000000000000184),einstein_radius=1.6),
mass_240=al.mp.PointMass(centre=(0.0,0.39000000000000185),einstein_radius=1.6),
mass_241=al.mp.PointMass(centre=(0.0,0.40000000000000185),einstein_radius=1.6),
mass_242=al.mp.PointMass(centre=(0.0,0.41000000000000186),einstein_radius=1.6),
mass_243=al.mp.PointMass(centre=(0.0,0.42000000000000187),einstein_radius=1.6),
mass_244=al.mp.PointMass(centre=(0.0,0.4300000000000019),einstein_radius=1.6),
mass_245=al.mp.PointMass(centre=(0.0,0.4400000000000019),einstein_radius=1.6),
mass_246=al.mp.PointMass(centre=(0.0,0.4500000000000019),einstein_radius=1.6),
mass_247=al.mp.PointMass(centre=(0.0,0.4600000000000019),einstein_radius=1.6),
mass_248=al.mp.PointMass(centre=(0.0,0.4700000000000019),einstein_radius=1.6),
mass_249=al.mp.PointMass(centre=(0.0,0.4800000000000019),einstein_radius=1.6),
mass_250=al.mp.PointMass(centre=(0.0,0.49000000000000193),einstein_radius=1.6),
mass_251=al.mp.PointMass(centre=(0.0,0.5000000000000019),einstein_radius=1.6),
mass_252=al.mp.PointMass(centre=(0.0,0.5100000000000019),einstein_radius=1.6),
mass_253=al.mp.PointMass(centre=(0.0,0.5200000000000019),einstein_radius=1.6),
mass_254=al.mp.PointMass(centre=(0.0,0.5300000000000019),einstein_radius=1.6),
mass_255=al.mp.PointMass(centre=(0.0,0.5400000000000019),einstein_radius=1.6),
mass_256=al.mp.PointMass(centre=(0.0,0.5500000000000019),einstein_radius=1.6),
mass_257=al.mp.PointMass(centre=(0.0,0.5600000000000019),einstein_radius=1.6),
mass_258=al.mp.PointMass(centre=(0.0,0.570000000000002),einstein_radius=1.6),
mass_259=al.mp.PointMass(centre=(0.0,0.580000000000002),einstein_radius=1.6),
mass_260=al.mp.PointMass(centre=(0.0,0.590000000000002),einstein_radius=1.6),
mass_261=al.mp.PointMass(centre=(0.0,0.600000000000002),einstein_radius=1.6),
mass_262=al.mp.PointMass(centre=(0.0,0.610000000000002),einstein_radius=1.6),
mass_263=al.mp.PointMass(centre=(0.0,0.620000000000002),einstein_radius=1.6),
mass_264=al.mp.PointMass(centre=(0.0,0.630000000000002),einstein_radius=1.6),
mass_265=al.mp.PointMass(centre=(0.0,0.640000000000002),einstein_radius=1.6),
mass_266=al.mp.PointMass(centre=(0.0,0.650000000000002),einstein_radius=1.6),
mass_267=al.mp.PointMass(centre=(0.0,0.660000000000002),einstein_radius=1.6),
mass_268=al.mp.PointMass(centre=(0.0,0.670000000000002),einstein_radius=1.6),
mass_269=al.mp.PointMass(centre=(0.0,0.680000000000002),einstein_radius=1.6),
mass_270=al.mp.PointMass(centre=(0.0,0.6900000000000021),einstein_radius=1.6),
mass_271=al.mp.PointMass(centre=(0.0,0.7000000000000021),einstein_radius=1.6),
mass_272=al.mp.PointMass(centre=(0.0,0.7100000000000021),einstein_radius=1.6),
mass_273=al.mp.PointMass(centre=(0.0,0.7200000000000021),einstein_radius=1.6),
mass_274=al.mp.PointMass(centre=(0.0,0.7300000000000021),einstein_radius=1.6),
mass_275=al.mp.PointMass(centre=(0.0,0.7400000000000021),einstein_radius=1.6),
mass_276=al.mp.PointMass(centre=(0.0,0.7500000000000021),einstein_radius=1.6),
mass_277=al.mp.PointMass(centre=(0.0,0.7600000000000021),einstein_radius=1.6),
mass_278=al.mp.PointMass(centre=(0.0,0.7700000000000021),einstein_radius=1.6),
mass_279=al.mp.PointMass(centre=(0.0,0.7800000000000021),einstein_radius=1.6),
mass_280=al.mp.PointMass(centre=(0.0,0.7900000000000021),einstein_radius=1.6),
mass_281=al.mp.PointMass(centre=(0.0,0.8000000000000022),einstein_radius=1.6),
mass_282=al.mp.PointMass(centre=(0.0,0.8100000000000022),einstein_radius=1.6),
mass_283=al.mp.PointMass(centre=(0.0,0.8200000000000022),einstein_radius=1.6),
mass_284=al.mp.PointMass(centre=(0.0,0.8300000000000022),einstein_radius=1.6),
mass_285=al.mp.PointMass(centre=(0.0,0.8400000000000022),einstein_radius=1.6),
mass_286=al.mp.PointMass(centre=(0.0,0.8500000000000022),einstein_radius=1.6),
mass_287=al.mp.PointMass(centre=(0.0,0.8600000000000022),einstein_radius=1.6),
mass_288=al.mp.PointMass(centre=(0.0,0.8700000000000022),einstein_radius=1.6),
mass_289=al.mp.PointMass(centre=(0.0,0.8800000000000022),einstein_radius=1.6),
mass_290=al.mp.PointMass(centre=(0.0,0.8900000000000022),einstein_radius=1.6),
mass_291=al.mp.PointMass(centre=(0.0,0.9000000000000022),einstein_radius=1.6),
mass_292=al.mp.PointMass(centre=(0.0,0.9100000000000023),einstein_radius=1.6),
mass_293=al.mp.PointMass(centre=(0.0,0.9200000000000023),einstein_radius=1.6),
mass_294=al.mp.PointMass(centre=(0.0,0.9300000000000023),einstein_radius=1.6),
mass_295=al.mp.PointMass(centre=(0.0,0.9400000000000023),einstein_radius=1.6),
mass_296=al.mp.PointMass(centre=(0.0,0.9500000000000023),einstein_radius=1.6),
mass_297=al.mp.PointMass(centre=(0.0,0.9600000000000023),einstein_radius=1.6),
mass_298=al.mp.PointMass(centre=(0.0,0.9700000000000023),einstein_radius=1.6),
mass_299=al.mp.PointMass(centre=(0.0,0.9800000000000023),einstein_radius=1.6),
mass_300=al.mp.PointMass(centre=(0.0,0.9900000000000023),einstein_radius=1.6),
mass_301=al.mp.PointMass(centre=(0.0,1.0000000000000022),einstein_radius=1.6),
mass_302=al.mp.PointMass(centre=(0.0,1.0100000000000022),einstein_radius=1.6),
mass_303=al.mp.PointMass(centre=(0.0,1.0200000000000022),einstein_radius=1.6),
mass_304=al.mp.PointMass(centre=(0.0,1.0300000000000022),einstein_radius=1.6),
mass_305=al.mp.PointMass(centre=(0.0,1.0400000000000023),einstein_radius=1.6),
mass_306=al.mp.PointMass(centre=(0.0,1.0500000000000023),einstein_radius=1.6),
mass_307=al.mp.PointMass(centre=(0.0,1.0600000000000023),einstein_radius=1.6),
mass_308=al.mp.PointMass(centre=(0.0,1.0700000000000023),einstein_radius=1.6),
mass_309=al.mp.PointMass(centre=(0.0,1.0800000000000023),einstein_radius=1.6),
mass_310=al.mp.PointMass(centre=(0.0,1.0900000000000023),einstein_radius=1.6),
mass_311=al.mp.PointMass(centre=(0.0,1.1000000000000023),einstein_radius=1.6),
mass_312=al.mp.PointMass(centre=(0.0,1.1100000000000023),einstein_radius=1.6),
mass_313=al.mp.PointMass(centre=(0.0,1.1200000000000023),einstein_radius=1.6),
mass_314=al.mp.PointMass(centre=(0.0,1.1300000000000023),einstein_radius=1.6),
mass_315=al.mp.PointMass(centre=(0.0,1.1400000000000023),einstein_radius=1.6),
mass_316=al.mp.PointMass(centre=(0.0,1.1500000000000024),einstein_radius=1.6),
mass_317=al.mp.PointMass(centre=(0.0,1.1600000000000024),einstein_radius=1.6),
mass_318=al.mp.PointMass(centre=(0.0,1.1700000000000024),einstein_radius=1.6),
mass_319=al.mp.PointMass(centre=(0.0,1.1800000000000024),einstein_radius=1.6),
mass_320=al.mp.PointMass(centre=(0.0,1.1900000000000024),einstein_radius=1.6),
mass_321=al.mp.PointMass(centre=(0.0,1.2000000000000024),einstein_radius=1.6),
mass_322=al.mp.PointMass(centre=(0.0,1.2100000000000024),einstein_radius=1.6),
mass_323=al.mp.PointMass(centre=(0.0,1.2200000000000024),einstein_radius=1.6),
mass_324=al.mp.PointMass(centre=(0.0,1.2300000000000024),einstein_radius=1.6),
mass_325=al.mp.PointMass(centre=(0.0,1.2400000000000024),einstein_radius=1.6),
mass_326=al.mp.PointMass(centre=(0.0,1.2500000000000024),einstein_radius=1.6),
mass_327=al.mp.PointMass(centre=(0.0,1.2600000000000025),einstein_radius=1.6),
mass_328=al.mp.PointMass(centre=(0.0,1.2700000000000025),einstein_radius=1.6),
mass_329=al.mp.PointMass(centre=(0.0,1.2800000000000025),einstein_radius=1.6),
mass_330=al.mp.PointMass(centre=(0.0,1.2900000000000025),einstein_radius=1.6),
mass_331=al.mp.PointMass(centre=(0.0,1.3000000000000025),einstein_radius=1.6),
mass_332=al.mp.PointMass(centre=(0.0,1.3100000000000025),einstein_radius=1.6),
mass_333=al.mp.PointMass(centre=(0.0,1.3200000000000025),einstein_radius=1.6),
mass_334=al.mp.PointMass(centre=(0.0,1.3300000000000025),einstein_radius=1.6),
mass_335=al.mp.PointMass(centre=(0.0,1.3400000000000025),einstein_radius=1.6),
mass_336=al.mp.PointMass(centre=(0.0,1.3500000000000025),einstein_radius=1.6),
mass_337=al.mp.PointMass(centre=(0.0,1.3600000000000025),einstein_radius=1.6),
mass_338=al.mp.PointMass(centre=(0.0,1.3700000000000025),einstein_radius=1.6),
mass_339=al.mp.PointMass(centre=(0.0,1.3800000000000026),einstein_radius=1.6),
mass_340=al.mp.PointMass(centre=(0.0,1.3900000000000026),einstein_radius=1.6),
mass_341=al.mp.PointMass(centre=(0.0,1.4000000000000026),einstein_radius=1.6),
mass_342=al.mp.PointMass(centre=(0.0,1.4100000000000026),einstein_radius=1.6),
mass_343=al.mp.PointMass(centre=(0.0,1.4200000000000026),einstein_radius=1.6),
mass_344=al.mp.PointMass(centre=(0.0,1.4300000000000026),einstein_radius=1.6),
mass_345=al.mp.PointMass(centre=(0.0,1.4400000000000026),einstein_radius=1.6),
mass_346=al.mp.PointMass(centre=(0.0,1.4500000000000026),einstein_radius=1.6),
mass_347=al.mp.PointMass(centre=(0.0,1.4600000000000026),einstein_radius=1.6),
mass_348=al.mp.PointMass(centre=(0.0,1.4700000000000026),einstein_radius=1.6),
mass_349=al.mp.PointMass(centre=(0.0,1.4800000000000026),einstein_radius=1.6),
mass_350=al.mp.PointMass(centre=(0.0,1.4900000000000027),einstein_radius=1.6),
mass_351=al.mp.PointMass(centre=(0.0,1.5000000000000027),einstein_radius=1.6),
mass_352=al.mp.PointMass(centre=(0.0,1.5100000000000027),einstein_radius=1.6),
mass_353=al.mp.PointMass(centre=(0.0,1.5200000000000027),einstein_radius=1.6),
mass_354=al.mp.PointMass(centre=(0.0,1.5300000000000027),einstein_radius=1.6),
mass_355=al.mp.PointMass(centre=(0.0,1.5400000000000027),einstein_radius=1.6),
mass_356=al.mp.PointMass(centre=(0.0,1.5500000000000027),einstein_radius=1.6),
mass_357=al.mp.PointMass(centre=(0.0,1.5600000000000027),einstein_radius=1.6),
mass_358=al.mp.PointMass(centre=(0.0,1.5700000000000027),einstein_radius=1.6),
mass_359=al.mp.PointMass(centre=(0.0,1.5800000000000027),einstein_radius=1.6),
mass_360=al.mp.PointMass(centre=(0.0,1.5900000000000027),einstein_radius=1.6),
mass_361=al.mp.PointMass(centre=(0.0,1.6000000000000028),einstein_radius=1.6),
mass_362=al.mp.PointMass(centre=(0.0,1.6100000000000028),einstein_radius=1.6),
mass_363=al.mp.PointMass(centre=(0.0,1.6200000000000028),einstein_radius=1.6),
mass_364=al.mp.PointMass(centre=(0.0,1.6300000000000028),einstein_radius=1.6),
mass_365=al.mp.PointMass(centre=(0.0,1.6400000000000028),einstein_radius=1.6),
mass_366=al.mp.PointMass(centre=(0.0,1.6500000000000028),einstein_radius=1.6),
mass_367=al.mp.PointMass(centre=(0.0,1.6600000000000028),einstein_radius=1.6),
mass_368=al.mp.PointMass(centre=(0.0,1.6700000000000028),einstein_radius=1.6),
mass_369=al.mp.PointMass(centre=(0.0,1.6800000000000028),einstein_radius=1.6),
mass_370=al.mp.PointMass(centre=(0.0,1.6900000000000028),einstein_radius=1.6),
mass_371=al.mp.PointMass(centre=(0.0,1.7000000000000028),einstein_radius=1.6),
mass_372=al.mp.PointMass(centre=(0.0,1.7100000000000029),einstein_radius=1.6),
mass_373=al.mp.PointMass(centre=(0.0,1.7200000000000029),einstein_radius=1.6),
mass_374=al.mp.PointMass(centre=(0.0,1.7300000000000029),einstein_radius=1.6),
mass_375=al.mp.PointMass(centre=(0.0,1.7400000000000029),einstein_radius=1.6),
mass_376=al.mp.PointMass(centre=(0.0,1.7500000000000029),einstein_radius=1.6),
mass_377=al.mp.PointMass(centre=(0.0,1.760000000000003),einstein_radius=1.6),
mass_378=al.mp.PointMass(centre=(0.0,1.770000000000003),einstein_radius=1.6),
mass_379=al.mp.PointMass(centre=(0.0,1.780000000000003),einstein_radius=1.6),
mass_380=al.mp.PointMass(centre=(0.0,1.790000000000003),einstein_radius=1.6),
mass_381=al.mp.PointMass(centre=(0.0,1.800000000000003),einstein_radius=1.6),
mass_382=al.mp.PointMass(centre=(0.0,1.810000000000003),einstein_radius=1.6),
mass_383=al.mp.PointMass(centre=(0.0,1.820000000000003),einstein_radius=1.6),
mass_384=al.mp.PointMass(centre=(0.0,1.830000000000003),einstein_radius=1.6),
mass_385=al.mp.PointMass(centre=(0.0,1.840000000000003),einstein_radius=1.6),
mass_386=al.mp.PointMass(centre=(0.0,1.850000000000003),einstein_radius=1.6),
mass_387=al.mp.PointMass(centre=(0.0,1.860000000000003),einstein_radius=1.6),
mass_388=al.mp.PointMass(centre=(0.0,1.870000000000003),einstein_radius=1.6),
mass_389=al.mp.PointMass(centre=(0.0,1.880000000000003),einstein_radius=1.6),
mass_390=al.mp.PointMass(centre=(0.0,1.890000000000003),einstein_radius=1.6),
mass_391=al.mp.PointMass(centre=(0.0,1.900000000000003),einstein_radius=1.6),
mass_392=al.mp.PointMass(centre=(0.0,1.910000000000003),einstein_radius=1.6),
mass_393=al.mp.PointMass(centre=(0.0,1.920000000000003),einstein_radius=1.6),
mass_394=al.mp.PointMass(centre=(0.0,1.930000000000003),einstein_radius=1.6),
mass_395=al.mp.PointMass(centre=(0.0,1.940000000000003),einstein_radius=1.6),
mass_396=al.mp.PointMass(centre=(0.0,1.950000000000003),einstein_radius=1.6),
mass_397=al.mp.PointMass(centre=(0.0,1.960000000000003),einstein_radius=1.6),
mass_398=al.mp.PointMass(centre=(0.0,1.970000000000003),einstein_radius=1.6),
mass_399=al.mp.PointMass(centre=(0.0,1.980000000000003),einstein_radius=1.6),
mass_400=al.mp.PointMass(centre=(0.0,1.990000000000003),einstein_radius=1.6),
mass_401=al.mp.PointMass(centre=(0.0,2.000000000000003),einstein_radius=1.6),

)

source_galaxy = al.Galaxy(
    redshift=1.0,
    light=al.lp.EllipticalSersic(
        centre=(0.1, 0.1),
        axis_ratio=0.8,
        phi=45.0,
        intensity=1.0,
        effective_radius=1.0,
        sersic_index=2.5,
    ),
)

tracer = al.Tracer.from_galaxies(galaxies=[lens_galaxy, source_galaxy])

# %%
aplt.tracer.profile_image(tracer=tracer, grid=grid)

# %% [markdown]
# To Simulate the Imaging data, we don't use the image plotted above. Instead, we use an image which has been generated  specifically for simulating an image, which pads the array it is computed on based on the shape of the PSF we  convolve the image with. This ensures edge-effects do not degrade our simulation's PSF convolution.

# %%
normal_image = tracer.profile_image_from_grid(grid=grid)
padded_image = tracer.padded_profile_image_from_grid_and_psf_shape(
    grid=grid, psf_shape_2d=psf.shape_2d
)
print(normal_image.shape)
print(padded_image.shape)
# Out:
# (40000,)
# (48400,)

# %% [markdown]
# Running through the simulator

# %%
simulator = al.simulator.imaging(
    shape_2d=grid.shape_2d,
    pixel_scales=0.1,
    sub_size=grid.sub_size,
    exposure_time=300.0,
    psf=psf,
    background_level=0.1,
    add_noise=True,
)

imaging = simulator.from_tracer(tracer=tracer)

# %% [markdown]
# Lets plot the image - we can see the image has been blurred due to the telescope optics and noise has been added.

# %%
aplt.imaging.image(imaging=imaging)

# %% [markdown]
# Now output our simulated data to hard-disk.

# %%
dataset_path="path to dataset"

# %%
imaging.output_to_fits(
    image_path=dataset_path + "image.fits",
    noise_map_path=dataset_path + "noise_map.fits",
    psf_path=dataset_path + "psf.fits",
    overwrite=True,
)
